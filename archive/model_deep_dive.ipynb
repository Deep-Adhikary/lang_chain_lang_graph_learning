# %% [markdown]
# ## Import dependencies

# %%
from langchain.chat_models import init_chat_model
from models import nova_micro_config
from rich import print

from langchain.messages import AIMessage, HumanMessage, SystemMessage

# %% [markdown]
# ### Create model using init chat model.

# %%
model = init_chat_model(
        model=nova_micro_config.model_id,
        model_provider="bedrock_converse",
        temperature=nova_micro_config.temperature,
        max_tokens=nova_micro_config.max_tokens,
        credentials_profile_name="sandbox",
    )

# %% [markdown]
# ### Model conversations and messages

# %%
conversation_by_dict = [
        {
            "role": "system",
            "content": "You are a helpful assistant that translates English to French.",
        },
        {"role": "user", "content": "Translate: I love programming."},
        {"role": "assistant", "content": "J'adore la programmation."},
        {"role": "user", "content": "Translate: I love building applications."},
    ]
conversation = [
        SystemMessage("You are a helpful assistant that translates English to French."),
        HumanMessage("Translate: I love programming."),
        AIMessage("J'adore la programmation."),
        HumanMessage("Is this correct? please explain"),
    ]
    ## Invoking Model with conversation
response = model.invoke(conversation)
print(response.text)
# Out:
# Yes, "J'adore la programmation" is correct and it means "I love programming" in French.
#
# Here's a breakdown of the translation:
# - "I" translates to "Je" in French.
# - "love" translates to "adore" in French.
# - "programming" translates to "la programmation" in French. "La" is the definite article "the" used here because
# "programmation" is a feminine noun in French.
#
# So, "J'adore la programmation" directly translates to "I love programming."

# %% [markdown]
# ### Streaming Response

# %%
# Invoking model with stream
output=""
for chunk in model.stream("How to use emergency breaking, while cycling in downhill?"):
    output=output+ chunk.text
print(output)
# Out:
# When cycling downhill, it's crucial to manage your speed and maintain control to prevent accidents. Here are some
# guidelines on how to use emergency braking effectively while cycling downhill:
#
# ### 1. **Anticipate Your Descent:**
#    - **Assess the Terrain:** Before you start descending, look ahead to identify where you can safely apply the
# brakes.
#    - **Plan Your Braking Points:** Identify potential braking points where you can slow down gradually.
#
# ### 2. **Use Your Brakes Gradually:**
#    - **Start Slow:** Begin braking gently to avoid skidding. This is especially important if the road is wet or
# slippery.
#    - **Front Brake First:** Apply the front brake first, but not too hard. The front brake is more powerful, and
# applying it too aggressively can cause you to lose control and flip over the handlebars.
#    - **Follow with the Rear Brake:** Once you've started slowing down with the front brake, you can apply the rear
# brake more firmly to maintain control.
#
# ### 3. **Technique:**
#    - **Brake Smoothly:** Apply the brakes in a smooth, controlled manner. Sudden, hard braking can cause you to
# lose traction and skid.
#    - **Avoid Locking the Wheels:** Keep your wheels turning to avoid locking them up. Locked wheels will cause you
# to skid and lose control.
#    - **Use Both Brakes:** For maximum control, use both brakes together, but be cautious with the front brake.
#
# ### 4. **Body Position:**
#    - **Lean Forward:** As you start to slow down, lean forward slightly to maintain balance. This helps to
# counteract the force that pushes you backward as you decelerate.
#    - **Keep Your Feet Down:** Keep your feet on the pedals to maintain control and be ready to balance if needed.
#
# ### 5. **Practice:**
#    - **Controlled Descents:** Practice controlled braking on less steep slopes to get a feel for how much braking
# power you need.
#    - **Emergency Stops:** Occasionally practice emergency stops in a safe, controlled environment to build
# confidence.
#
# ### 6. **Additional Tips:**
#    - **Use Your Feet:** If you have a fixed-gear bike or a single-speed bike without brakes, you can use your feet
# to slow down by "toeing out" (pointing your feet outward) to resist the pedals.
#    - **Gear Selection:** Use lower gears to make the descent easier and to have more control over your speed.
#
# ### Safety First:
# - **Wear Protective Gear:** Always wear a helmet and consider additional protective gear like gloves, knee pads,
# and elbow pads.
# - **Stay Alert:** Be aware of your surroundings, including other cyclists, pedestrians, and road conditions.
#
# By practicing these techniques and maintaining a safe, controlled approach, you can effectively manage your speed
# and maintain control while cycling downhill.

# %% [markdown]
# ### Model batch processing:
#
# This helps to run request in batch in parallel and help to reduce cost. We restrict the concurrency with config

# %%
batched = [
    "How to preapare for sleep",
    "Does cow folly any bed time routine",
    "Should I hire a navy seal for protecting my bicycle?",
]
responses = model.batch(batched, config={"max_concurrency": 5})
for response in responses:
    print(response.text)
# Out:
# Preparing for sleep is essential for achieving restful and restorative sleep. Here are some steps you can take to
# prepare your body and mind for a good night's sleep:
#
# ### 1. **Create a Consistent Sleep Schedule**
#    - Go to bed and wake up at the same time every day, even on weekends.
#    - This helps regulate your body's internal clock.
#
# ### 2. **Wind Down Before Bedtime**
#    - Start a bedtime routine that signals to your body that it's time to wind down.
#    - Activities might include reading a book, taking a warm bath, or practicing gentle yoga.
#
# ### 3. **Limit Screen Time**
#    - Avoid screens (phones, tablets, computers, TVs) at least an hour before bed.
#    - The blue light emitted by screens can interfere with the production of melatonin, the hormone that regulates
# sleep.
#
# ### 4. **Create a Comfortable Sleep Environment**
#    - Keep your bedroom cool, quiet, and dark.
#    - Use comfortable bedding and pillows.
#    - Consider using blackout curtains, a white noise machine, or a fan to create an optimal sleep environment.
#
# ### 5. **Watch Your Diet**
#    - Avoid large meals, caffeine, and alcohol close to bedtime.
#    - Caffeine can stay in your system for several hours, and alcohol can disrupt sleep cycles.
#    - Opt for a light snack if you're hungry, such as a small piece of fruit or a handful of nuts.
#
# ### 6. **Exercise Regularly**
#    - Engage in regular physical activity, but try to finish vigorous workouts at least a few hours before bedtime.
#    - Exercise can help you fall asleep faster and enjoy deeper sleep.
#
# ### 7. **Manage Stress and Anxiety**
#    - Practice relaxation techniques such as deep breathing, meditation, or progressive muscle relaxation.
#    - Journaling about your thoughts and worries before bed can help clear your mind.
#
# ### 8. **Limit Naps**
#    - If you need to nap, keep it short (20-30 minutes) and avoid napping late in the day.
#    - Long or late naps can interfere with your ability to sleep well at night.
#
# ### 9. **Consider Sleep Aids Wisely**
#    - If you struggle with sleep, consider talking to a healthcare provider about sleep aids or therapies.
#    - Avoid relying on sleep aids as a long-term solution.
#
# ### 10. **Mind Your Medications**
#    - Check with your doctor about any medications that might interfere with your sleep.
#    - Some medications can cause insomnia as a side effect.
#
# By incorporating these practices into your daily routine, you can improve the quality of your sleep and wake up
# feeling more refreshed and ready to tackle the day.
# Cows do not have a bedtime routine in the way humans do, as their natural behaviors and sleep patterns are quite
# different from ours. Here’s a bit more detail about how cows manage their rest:
#
# 1. **Resting Periods**: Cows typically rest for several hours during the day. They lie down to rest and ruminate
# (chew their cud), which is a process of digesting their food. This usually happens in short bursts throughout the
# day.
#
# 2. **Sleep**: Cows sleep in a standing position, thanks to a special ligament in their legs called the "stay
# apparatus," which allows them to rest without falling over. They can fall asleep standing up and will lie down for
# deeper sleep when needed.
#
# 3. **Daily Patterns**: Cows are more active during the day and tend to be less active at night. Their activity
# levels can vary based on factors like feeding schedules, weather, and overall health.
#
# 4. **Rumination**: This is a significant part of their digestive process and happens while they are lying down.
# Rumination involves regurgitating food, chewing it again, and swallowing it back down to aid digestion.
#
# In summary, while cows do not have a structured bedtime routine, they do have periods of rest and sleep that are
# integrated into their daily activities.
# Hiring a Navy SEAL for protecting your bicycle is an extreme and unnecessary measure. Navy SEALs are highly trained
# military operatives who are typically deployed to handle complex, high-risk situations such as counter-terrorism,
# special reconnaissance, and direct action missions.
#
# Protecting a bicycle generally falls under standard security measures that can be handled by a variety of less
# specialized and far more cost-effective means. Here are some practical and appropriate steps you can take:
#
# 1. **Secure Parking**: Always park your bicycle in a secure, well-lit area. Many places offer bike lockers or
# designated bike parking areas.
#
# 2. **Bike Locks**: Invest in a high-quality bike lock. U-locks and D-locks are particularly effective at deterring
# theft.
#
# 3. **Insurance**: Consider getting bike insurance to cover theft or damage.
#
# 4. **Visibility**: Use bright or reflective gear if you're cycling in low-light conditions.
#
# 5. **Personal Security**: If you're in an area where you feel particularly vulnerable, consider walking or using
# public transportation instead.
#
# Remember, the level of protection required should match the perceived risk. Hiring a Navy SEAL is not a practical
# or financially reasonable solution for bicycle security.

# %% [markdown]
# ### Batch as completed

# %%
for response in model.batch_as_completed(batched):
    print(response[0],response[1].text)
# Out:
# 2 Hiring a Navy SEAL for the protection of your bicycle is an extreme and unnecessary measure. Navy SEALs are
# highly trained military operatives who are specialized in combat, reconnaissance, and special operations. Their
# skills and training are suited for situations involving national security, combat, and high-risk operations.
#
# Protecting a bicycle generally falls under standard security measures that can be handled by local law enforcement,
# private security services, or even personal precautions like:
#
# 1. **Secure Parking:** Use a reputable bike shop or a well-lit, secure area when parking.
# 2. **Locks:** Invest in high-quality bike locks such as U-locks or D-locks.
# 3. **Insurance:** Consider insuring your bicycle against theft.
# 4. **Awareness:** Be aware of your surroundings and avoid leaving your bike unattended in high-risk areas.
#
# Unless you are dealing with a specific, high-risk situation that justifies such extreme measures, it is neither
# practical nor cost-effective to hire a Navy SEAL for bicycle protection. It’s important to use appropriate and
# proportionate security measures for your needs.
# 1 Cows, like many animals, do not have a bedtime routine in the way humans understand it. They are primarily
# diurnal, meaning they are active during the day and rest during the night. However, their behavior can be
# influenced by various factors such as feeding schedules, environmental conditions, and the need for social
# interaction.
#
# Here are some typical behaviors of cows that might give the impression of a routine:
#
# 1. **Feeding**: Cows are often fed multiple times a day. They might be more active during feeding times and then
# rest afterward.
#
# 2. **Resting**: Cows spend a significant amount of time resting. They lie down to ruminate, which is a process
# where they chew their cud and digest their food. This usually happens in the afternoon and evening.
#
# 3. **Social Interaction**: Cows are social animals and may engage in social behaviors like grooming or standing
# together, which can happen at any time of the day.
#
# 4. **Watering**: Cows need regular access to water, and they might drink frequently throughout the day.
#
# 5. **Movement**: Cows may move around to find food, water, or to rest in a more comfortable spot.
#
# While cows do not have a structured bedtime routine, their daily activities follow a somewhat predictable pattern
# based on their natural behaviors and the routines established by humans who manage them.
# 0 Preparing for sleep is essential for achieving restful and restorative sleep. Here are some steps you can follow
# to help you prepare for a good night's sleep:
#
# ### 1. **Create a Consistent Sleep Schedule**
#    - Go to bed and wake up at the same time every day, even on weekends.
#    - Aim for 7-9 hours of sleep per night.
#
# ### 2. **Wind Down Routine**
#    - Establish a pre-sleep routine to signal to your body that it’s time to wind down.
#    - Activities might include reading a book, taking a warm bath, practicing meditation or deep breathing
# exercises, or listening to calming music.
#
# ### 3. **Limit Screen Time**
#    - Avoid screens (phones, tablets, computers, TVs) at least an hour before bed.
#    - The blue light from screens can interfere with the production of melatonin, the hormone that regulates sleep.
#
# ### 4. **Create a Comfortable Sleep Environment**
#    - Keep your bedroom cool, quiet, and dark.
#    - Use comfortable bedding and a supportive mattress.
#    - Consider using blackout curtains, a white noise machine, or a fan to improve sleep conditions.
#
# ### 5. **Watch What You Eat and Drink**
#    - Avoid large meals, caffeine, and alcohol close to bedtime.
#    - Caffeine can take several hours to leave your system, and alcohol can disrupt sleep patterns.
#
# ### 6. **Get Regular Exercise**
#    - Engage in regular physical activity during the day.
#    - Avoid vigorous exercise close to bedtime, as it can be stimulating.
#
# ### 7. **Manage Stress**
#    - Practice stress-reducing techniques such as mindfulness, yoga, or journaling.
#    - Consider talking to someone about any worries or stress you might be experiencing.
#
# ### 8. **Limit Naps**
#    - If you need to nap, keep it short (20-30 minutes) and avoid napping late in the day.
#
# ### 9. **Avoid Clock-Watching**
#    - Don’t spend time worrying about falling asleep. This can create anxiety that makes it harder to sleep.
#    - If you can’t fall asleep within 20 minutes, get out of bed and do a relaxing activity until you feel sleepy.
#
# ### 10. **Consider Sleep Aids**
#    - Herbal supplements like melatonin might help some people, but it’s best to consult a healthcare provider
# before starting any supplement.
#
# ### 11. **Practice Good Sleep Hygiene**
#    - Avoid smoking and excessive drinking.
#    - Keep your sleep environment as consistent and predictable as possible.
#
# By incorporating these practices into your daily routine, you can improve the quality of your sleep and wake up
# feeling refreshed and ready for the day.

# %% [markdown]
# ## Tool Calling
#
# - Tool is an external function or coroutine which model can execute
# - Tool needs to be bounded with model with the `bind` method to make sure model can use that tool

# %% [markdown]
# #### Create a Tool

# %%
from langchain.tools import tool

@tool
def get_weather(location:str)-> str:
    """Get weather for a location
    """
    if location in ["London","Cambridge","Bath"]:
        return f"It is always raining in UK. So City {location} is not an exception"
    return f"It is sunny in {location}"

# %% [markdown]
# #### Bind tool and invoke

# %%
# bind tools
model_with_tool=model.bind_tools([get_weather])

messages=[HumanMessage("What's the weather like in Honululu, Bath and London ?")]
# Model generate tool calls
response = model_with_tool.invoke(messages)
messages.append(response)
print(response.tool_calls)
# for tool_call in response.tool_calls:
#     # View tool calls made by the model
#     print(f"Tool: {tool_call['name']}")
#     print(f"Args: {tool_call['args']}")
# Out:
# [
#     {
#         'name': 'get_weather',
#         'args': {'location': 'Honolulu'},
#         'id': 'tooluse_NxKMI6FtSweqUsnxpqxprA',
#         'type': 'tool_call'
#     },
#     {
#         'name': 'get_weather',
#         'args': {'location': 'Bath'},
#         'id': 'tooluse_XrCY3gQHSPuKaa1vWwWxzQ',
#         'type': 'tool_call'
#     },
#     {
#         'name': 'get_weather',
#         'args': {'location': 'London'},
#         'id': 'tooluse_eQPNXEdfRB-Xt7SkyWOx0w',
#         'type': 'tool_call'
#     }
# ]

# %%
# Execute tool call and collect result
for tool_call in response.tool_calls:
    # Execute the tool call with generated arguments
    print(tool_call)
    tool_result=get_weather.invoke(tool_call)
    messages.append(tool_result)

# Construct the final message
final_response= model_with_tool.invoke(messages)
print(final_response.text)
# Out:
# {
#     'name': 'get_weather',
#     'args': {'location': 'Honolulu'},
#     'id': 'tooluse_NxKMI6FtSweqUsnxpqxprA',
#     'type': 'tool_call'
# }
# {'name': 'get_weather', 'args': {'location': 'Bath'}, 'id': 'tooluse_XrCY3gQHSPuKaa1vWwWxzQ', 'type': 'tool_call'}
# {
#     'name': 'get_weather',
#     'args': {'location': 'London'},
#     'id': 'tooluse_eQPNXEdfRB-Xt7SkyWOx0w',
#     'type': 'tool_call'
# }
# Here is the current weather for the locations you inquired about:
#
# - Honolulu: It is sunny.
# - Bath: It is always raining, typical for the UK.
# - London: It is always raining, typical for the UK.
#
# If you need more detailed information or have any other questions, feel free to ask!

# %% [markdown]
# ### Structured Output

# %% [markdown]
# #### Using Pydantic models

# %%
from pydantic import BaseModel, Field

class Movie(BaseModel):
    title: str = Field(...,description="Movie title. E.g. Titanic, Intersteller")
    year: int = Field(...,description="The year movie is published")
    director: str = Field(..., description="Director of the movie. E.g. James Cameron")
    rating: float = Field(..., description="Rating of the movie, you will decide with your knowledge")
    summary: str = Field(...,description="a sort summary of the movie")

# %% [markdown]
# #### Using Typedict

# %%
from typing_extensions import TypedDict, Annotated


class MovieDict(TypedDict):
    title: Annotated[str, ..., "Movie title. E.g. Titanic, Intersteller"]
    year: Annotated[int, ..., "The year movie is published"]
    director: Annotated[str, ..., "Director of the movie. E.g. James Cameron"]
    rating: Annotated[
        float, ..., "Rating of the movie, you will decide with your knowledge"
    ]
    summary: Annotated[str, ..., "a sort summary of the movie"]

# %% [markdown]
# #### Json Schema

# %%
movie_schema = {
    "title": "Movie",
    "description": "A movie with details",
    "type": "object",
    "properties": {
        "title": {
            "type": "string",
            "description": "The title of the movie"
        },
        "year": {
            "type": "integer",
            "description": "The year the movie was released"
        },
        "director": {
            "type": "string",
            "description": "The director of the movie"
        },
        "rating": {
            "type": "number",
            "description": "The movie's rating out of 10"
        },
         "summary": {
            "type": "string",
            "description": "a sort summary of the movie"
        },

    },
    "required": ["title", "year", "director", "rating","summary"]
}

# %%
model_with_structure = model.with_structured_output(Movie)
response = model_with_structure.invoke(
    [
        SystemMessage("You are a movie critiq, your task is to provide movie details. User may provide more that one"),
        HumanMessage("Harry potter and the chember of secrets, Intersteller"),
    ]
)
print(response)
# Out:
# Movie(
#     title='Harry Potter and the Chamber of Secrets',
#     year=2002,
#     director='Chris Columbus',
#     rating=7.8,
#     summary='Harry Potter returns to Hogwarts for his second year where he discovers the Chamber of Secrets has
# been opened, unleashing a monster that petrifies students.'
# )

# %%
model_with_structure=model.with_structured_output(movie_schema,method="json_schema", include_raw=True)
response = model_with_structure.invoke(
    [
        SystemMessage("You are a movie critiq, your task is to provide movie details. User may provide more that one"),
        HumanMessage("Harry potter and the chember of secrets, Intersteller"),
    ]
)
print(response)
# Out:
# AIMessage(
#     content=[
#         {
#             'type': 'tool_use',
#             'name': 'Movie',
#             'input': {
#                 'summary': 'Harry Potter returns to Hogwarts for his second year where he discovers the Chamber of
# Secrets, a long-forgotten chamber containing a monster that only he can defeat.',
#                 'year': 2002,
#                 'director': 'Chris Columbus',
#                 'rating': 7.8,
#                 'title': 'Harry potter and the chamber of secrets'
#             },
#             'id': 'tooluse_C8MpIg8WSX-cpG4ZzZI9lg'
#         },
#         {
#             'type': 'tool_use',
#             'name': 'Movie',
#             'input': {
#                 'summary': "A team of explorers travel through a wormhole in space in an attempt to ensure
# humanity's survival.",
#                 'year': 2014,
#                 'director': 'Christopher Nolan',
#                 'rating': 8.6,
#                 'title': 'Interstellar'
#             },
#             'id': 'tooluse_x1iAapboSluOohBj3DCnhQ'
#         }
#     ],
#     additional_kwargs={},
#     response_metadata={
#         'ResponseMetadata': {
#             'RequestId': 'f3098d71-5d8d-4da6-a38e-e0a245db18cc',
#             'HTTPStatusCode': 200,
#             'HTTPHeaders': {
#                 'date': 'Mon, 22 Dec 2025 19:52:19 GMT',
#                 'content-type': 'application/json',
#                 'content-length': '834',
#                 'connection': 'keep-alive',
#                 'x-amzn-requestid': 'f3098d71-5d8d-4da6-a38e-e0a245db18cc'
#             },
#             'RetryAttempts': 0
#         },
#         'stopReason': 'tool_use',
#         'metrics': {'latencyMs': [675]},
#         'model_provider': 'bedrock_converse',
#         'model_name': 'amazon.nova-micro-v1:0'
#     },
#     id='lc_run--019b479e-a7c1-7382-afd1-ac88d8294db4-0',
#     tool_calls=[
#         {
#             'name': 'Movie',
#             'args': {
#                 'summary': 'Harry Potter returns to Hogwarts for his second year where he discovers the Chamber of
# Secrets, a long-forgotten chamber containing a monster that only he can defeat.',
#                 'year': 2002,
#                 'director': 'Chris Columbus',
#                 'rating': 7.8,
#                 'title': 'Harry potter and the chamber of secrets'
#             },
#             'id': 'tooluse_C8MpIg8WSX-cpG4ZzZI9lg',
#             'type': 'tool_call'
#         },
#         {
#             'name': 'Movie',
#             'args': {
#                 'summary': "A team of explorers travel through a wormhole in space in an attempt to ensure
# humanity's survival.",
#                 'year': 2014,
#                 'director': 'Christopher Nolan',
#                 'rating': 8.6,
#                 'title': 'Interstellar'
#             },
#             'id': 'tooluse_x1iAapboSluOohBj3DCnhQ',
#             'type': 'tool_call'
#         }
#     ],
#     usage_metadata={
#         'input_tokens': 532,
#         'output_tokens': 112,
#         'total_tokens': 644,
#         'input_token_details': {'cache_creation': 0, 'cache_read': 0}
#     }
# )

# %%
print(model.profile)
# Out:
# {
#     'max_input_tokens': 128000,
#     'max_output_tokens': 8192,
#     'image_inputs': False,
#     'audio_inputs': False,
#     'video_inputs': False,
#     'image_outputs': False,
#     'audio_outputs': False,
#     'video_outputs': False,
#     'reasoning_output': False,
#     'tool_calling': True,
#     'image_url_inputs': True,
#     'pdf_inputs': True,
#     'pdf_tool_message': True,
#     'image_tool_message': True
# }

# %% [markdown]
# ### Rate Limiting

# %%
from langchain_core.rate_limiters import InMemoryRateLimiter
from models import nova_pro_config


in_memory_limiter=InMemoryRateLimiter(
    requests_per_second=0.1, # 1 Request every 10s
    check_every_n_seconds=0.1, # Check every 100ms wheather allowed to make a request
    max_bucket_size=10 # controls maximum burst size
)

model_nova_pro = init_chat_model(
        model=nova_pro_config.model_id,
        model_provider="bedrock_converse",
        temperature=nova_pro_config.temperature,
        max_tokens=nova_pro_config.max_tokens,
        credentials_profile_name="sandbox",
        rate_limiter=in_memory_limiter 
    )

# %% [markdown]
# ##### Token usage

# %%
from langchain_core.callbacks import UsageMetadataCallbackHandler
from langchain_core.runnables import RunnableConfig
usage_metadata_callback_handler=UsageMetadataCallbackHandler()
confgis= RunnableConfig(
    run_id="EF0FE3BD-B0F1-4E9F-A210-CC9BC358A17F",
    run_name="Dragon emperor",
    max_concurrency=1,
    recursion_limit=1,
    metadata={"Dragon Name": "Tarin" },
    callbacks=[usage_metadata_callback_handler]
)

response=model_nova_pro.invoke("How to train your dragon", config=confgis)
print(response.text)
print(usage_metadata_callback_handler.usage_metadata)
# Out:
# "How to Train Your Dragon" is a popular series of children's books by Cressida Cowell, which was later adapted into
# successful animated films by DreamWorks. If you're looking to train a dragon in the spirit of the series, here’s a
# fun, fictional guide inspired by the story:
#
# ### Step-by-Step Guide to Training Your Dragon
#
# #### 1. **Understanding Your Dragon**
#    - **Research:** Learn about different dragon species. Each type has unique traits, strengths, and weaknesses.
#    - **Observation:** Spend time watching your dragon’s behavior, eating habits, and preferences.
#
# #### 2. **Building Trust**
#    - **Be Patient:** Dragons, like any other creatures, need time to trust humans.
#    - **Offer Food:** Start by offering your dragon food. This can be a great way to build a positive association
# with you.
#    - **Speak Gently:** Use a calm and gentle tone when approaching your dragon.
#
# #### 3. **Creating a Bond**
#    - **Spend Time Together:** Engage in activities that your dragon enjoys. This could be flying, playing, or
# simply resting together.
#    - **Learn Body Language:** Understand the dragon’s signals. Tail flicks, wing positions, and growls can tell you
# a lot about their mood.
#
# #### 4. **Basic Training**
#    - **Simple Commands:** Start with simple commands like “come” or “stay.” Use treats as rewards for following
# commands.
#    - **Consistency:** Be consistent with your commands and rewards. Dragons respond well to routine.
#
# #### 5. **Advanced Training**
#    - **Tricks and Maneuvers:** Once your dragon has mastered basic commands, you can start teaching more complex
# tricks and flying maneuvers.
#    - **Teamwork Exercises:** Engage in activities that require cooperation, such as obstacle courses or mock
# battles.
#
# #### 6. **Safety First**
#    - **Protective Gear:** Wear appropriate gear to protect yourself during training sessions.
#    - **Secure Environment:** Ensure the training area is safe and free from hazards.
#
# #### 7. **Celebrate Successes**
#    - **Rewards:** Always reward your dragon for successful training sessions with treats, praise, or playtime.
#    - **Bonding Activities:** End training sessions with fun activities to strengthen your bond.
#
# ### Tips for Success
# - **Be Patient:** Training takes time. Don’t rush the process.
# - **Stay Positive:** Dragons can sense your emotions. Stay positive and encouraging.
# - **Have Fun:** Enjoy the process and the unique relationship you’re building with your dragon.
#
# Remember, this is a fictional guide inspired by the "How to Train Your Dragon" series. In reality, dragons do not
# exist, but the principles of patience, trust, and positive reinforcement can be applied to training real animals.
# {
#     'amazon.nova-pro-v1:0': {
#         'input_tokens': 5,
#         'output_tokens': 579,
#         'total_tokens': 584,
#         'input_token_details': {'cache_creation': 0, 'cache_read': 0}
#     }
# }

# %% [markdown]
# ##### Token usage with callback handler
# Useful when multiple modles call

# %%
from langchain_core.callbacks import get_usage_metadata_callback

with get_usage_metadata_callback() as cb:
    print(model.invoke("How to train your dragon").text)
    print(model_nova_pro.invoke("How to train your dragon").text)

    print(cb.usage_metadata)
# Out:
# "How to Train Your Dragon" is a popular franchise that includes a book series by Cressida Cowell, an animated movie
# series by DreamWorks, and a television series. The story revolves around a young Viking named Hiccup, who befriends
# a dragon named Toothless. Here's a guide on how to train your dragon, inspired by the franchise:
#
# ### Understanding the Basics
#
# 1. **Respect and Trust**:
#    - Build a bond with your dragon. Respect its intelligence and feelings.
#    - Trust is crucial. Dragons are not to be feared but understood.
#
# 2. **Observation**:
#    - Spend time observing your dragon’s behavior and habits.
#    - Learn its unique characteristics, likes, and dislikes.
#
# ### Training Techniques
#
# 1. **Communication**:
#    - Use body language and vocal cues to communicate with your dragon.
#    - Mimic sounds that dragons make to establish a connection.
#
# 2. **Feeding**:
#    - Provide a balanced diet. Dragons often eat meat, but some may have different preferences.
#    - Establish a feeding routine to build trust.
#
# 3. **Training Exercises**:
#    - **Basic Commands**: Start with simple commands like “come” or “stay.”
#    - **Flight Training**: Practice flying together. Start with short distances and gradually increase.
#    - **Games**: Engage in playful activities to strengthen your bond and improve skills.
#
# 4. **Patience and Consistency**:
#    - Training takes time. Be patient and consistent with your efforts.
#    - Reward good behavior with treats or affection.
#
# ### Safety Measures
#
# 1. **Safety Gear**:
#    - Use protective gear like helmets and gloves when training.
#    - Ensure your dragon is comfortable with the equipment.
#
# 2. **Controlled Environment**:
#    - Train in a safe, enclosed area to prevent accidents.
#    - Gradually introduce your dragon to open spaces.
#
# ### Advanced Training
#
# 1. **Advanced Maneuvers**:
#    - Once your dragon is comfortable, you can teach more complex maneuvers like loops and dives.
#    - Always ensure both you and your dragon are prepared for these advanced moves.
#
# 2. **Teamwork**:
#    - Involve other dragons or Viking riders to practice teamwork.
#    - Participate in dragon races or competitions to hone your skills.
#
# ### Maintaining the Bond
#
# 1. **Regular Check-ups**:
#    - Ensure your dragon is healthy. Regular check-ups with a dragon healer can prevent issues.
#
# 2. **Quality Time**:
#    - Spend time with your dragon outside of training. This helps maintain the bond.
#    - Engage in activities like watching the sunset or exploring new places.
#
# ### Tips from the Franchise
#
# 1. **Hiccup’s Approach**:
#    - Hiccup’s method of training is based on understanding and mutual respect.
#    - He never forces Toothless to do anything it doesn’t want to do.
#
# 2. **Community Involvement**:
#    - Involve your Viking community in dragon training and care.
#    - Share knowledge and experiences to improve everyone’s skills.
#
# Remember, training a dragon is a unique and personal journey. Each dragon has its own personality and may require
# different approaches. Always prioritize safety and mutual respect in your training endeavors.
# "How to Train Your Dragon" is a popular series of children's books by Cressida Cowell, which has also been adapted
# into successful movies and a TV series. If you're looking to train a dragon in the spirit of the series, here’s a
# fun, imaginative guide inspired by the story:
#
# ### Step-by-Step Guide to Training Your Dragon
#
# #### 1. **Understanding Your Dragon**
#    - **Research:** Learn about different dragon species. Each type has unique traits, strengths, and weaknesses.
#    - **Observation:** Spend time watching your dragon. Note its behaviors, preferences, and habits.
#
# #### 2. **Building Trust**
#    - **Approach Calmly:** Dragons can be sensitive to sudden movements. Approach slowly and speak in a calm, gentle
# tone.
#    - **Offer Food:** Dragons, like any creature, appreciate food. Offer their favorite treats to build a positive
# association with you.
#
# #### 3. **Communication**
#    - **Body Language:** Dragons communicate through body language. Learn to read their signals (e.g., tail
# movements, wing positions).
#    - **Sounds:** Some dragons respond to specific sounds or whistles. Experiment to find what your dragon likes.
#
# #### 4. **Basic Commands**
#    - **Simple Commands:** Start with basic commands like “come,” “stay,” and “fly.” Use treats as rewards for
# following commands.
#    - **Consistency:** Be consistent with your commands and rewards. Dragons learn best with repetition.
#
# #### 5. **Training Exercises**
#    - **Fetch:** Throw a favorite toy or object and encourage your dragon to bring it back.
#    - **Obstacle Course:** Set up a simple obstacle course to help your dragon build agility and trust in you.
#    - **Flight Practice:** If your dragon can fly, practice short flights together. Ensure the area is safe and free
# of obstacles.
#
# #### 6. **Safety First**
#    - **Secure Environment:** Ensure the training area is safe. Remove any hazardous objects and secure the space to
# prevent escapes.
#    - **Emergency Plan:** Have a plan in case things go wrong. Know how to calm your dragon and seek help if needed.
#
# #### 7. **Bonding Activities**
#    - **Grooming:** Many dragons enjoy being groomed. Brushing their scales can be a bonding experience.
#    - **Playtime:** Engage in play activities that both you and your dragon enjoy. This strengthens your bond and
# makes training more enjoyable.
#
# #### 8. **Patience and Persistence**
#    - **Be Patient:** Training takes time. Celebrate small victories and be patient with setbacks.
#    - **Stay Positive:** Keep training sessions fun and positive. Dragons respond best to encouragement and praise.
#
# ### Additional Tips
# - **Health Check:** Ensure your dragon is healthy. A sick dragon won’t train well.
# - **Socialization:** If possible, introduce your dragon to other friendly dragons. Social interaction can be
# beneficial.
#
# Remember, training a dragon is a imaginative exercise, but the principles of trust, patience, and positive
# reinforcement are universal and can be applied to training any pet or animal.
# {
#     'amazon.nova-micro-v1:0': {
#         'input_tokens': 5,
#         'output_tokens': 649,
#         'total_tokens': 654,
#         'input_token_details': {'cache_creation': 0, 'cache_read': 0}
#     },
#     'amazon.nova-pro-v1:0': {
#         'input_tokens': 5,
#         'output_tokens': 642,
#         'total_tokens': 647,
#         'input_token_details': {'cache_creation': 0, 'cache_read': 0}
#     }
# }
